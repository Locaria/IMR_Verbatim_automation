# %%
import requests
import time
import pandas as pd

# %%
# Credenciais
username = 'yngrid.figlioli_PM'
password = 'ExpectoPatronum1!'

# Função para autenticar e obter o token
def get_auth_token():
    url = "https://cloud.memsource.com/web/api2/v1/auth/login"
    credentials = {
        "userName": username,
        "password": password
    }

    response = requests.post(url, json=credentials)

    print("Auth response status code:", response.status_code)
    print("Auth response text:", response.text)

    if response.status_code == 200:
        token_info = response.json()
        access_token = token_info.get("token")
        print("Authentication token:", access_token)
        return access_token
    else:
        print("Failed to authenticate. Status code:", response.status_code)
        print("Response:", response.text)
        raise SystemExit

# Obter o token de autenticação
access_token = get_auth_token()

# Adicionar uma pequena pausa para garantir que o token seja processado
time.sleep(1)

# Verificar se o token está correto
print("Using token:", access_token)

# Configurar o cabeçalho de autorização
headers = {
    "Authorization": f"Bearer {access_token}"
}

# Log dos cabeçalhos para depuração
print("Authorization headers:", headers)
# Out:
# Auth response status code: 200
# Auth response text: {"user":{"userName":"yngrid.figlioli_PM","uid":"CNFAysVlnxXg4xj5sOXYS0","id":"1198300","firstName":"Yngrid","lastName":"Figlioli","role":"PROJECT_MANAGER","email":"yngrid.figlioli@locaria.com"},"token":"kKXFEcDRZa1HGVZLIGbRTtyLtMkdp2lOhHVgiPw3BgrybrTan3rVbcezirO6kT1e2","lastInvalidateAllSessionsPerformed":"2024-03-08T09:18:10+0000","expires":"2024-05-23T09:23:19+0000"}
# Authentication token: kKXFEcDRZa1HGVZLIGbRTtyLtMkdp2lOhHVgiPw3BgrybrTan3rVbcezirO6kT1e2
# Using token: kKXFEcDRZa1HGVZLIGbRTtyLtMkdp2lOhHVgiPw3BgrybrTan3rVbcezirO6kT1e2
# Authorization headers: {'Authorization': 'Bearer kKXFEcDRZa1HGVZLIGbRTtyLtMkdp2lOhHVgiPw3BgrybrTan3rVbcezirO6kT1e2'}

# %%
# URL para obter os projetos
get_projects_url = "https://cloud.memsource.com/web/api2/v1/projects"
print("Projects URL:", get_projects_url)
# Out:
# Projects URL: https://cloud.memsource.com/web/api2/v1/projects

# %%
headers = {
    "Authorization": f"ApiToken {access_token}"
}

# %%
# Função para obter todos os projetos paginados filtrados por cliente
def get_projects_by_client(client_name):
    projects_list = []
    page_number = 0
    page_size = 50  # Ajuste conforme necessário

    while True:
        projects_url = f"https://cloud.memsource.com/web/api2/v1/projects?pageNumber={page_number}&pageSize={page_size}&clientName={client_name}"
        projects_response = requests.get(projects_url, headers=headers)

        if projects_response.status_code == 200:
            projects_data = projects_response.json().get('content')
            if not projects_data:
                break
            projects_list.extend(projects_data)
            page_number += 1
        else:
            raise Exception(f"Failed to fetch projects. Status code: {projects_response.status_code}, Response: {projects_response.text}")

    return projects_list

# Obter todos os projetos do cliente 'Harris Poll'
client_name = "Harris Poll"
all_projects_data = get_projects_by_client(client_name)

# Criar uma lista de dicionários com os dados dos projetos
projects_list = []
for project in all_projects_data:
    project_dict = {}
    for key, value in project.items():
        if isinstance(value, dict):
            for sub_key, sub_value in value.items():
                project_dict[f"{key}.{sub_key}"] = sub_value
        else:
            project_dict[key] = value
    projects_list.append(project_dict)

# Criar o DataFrame
df = pd.DataFrame(projects_list)

# %%
df
# Out:
#       projectWorkflowSettings.propagateTranslationsToLowerWfDuringUpdateSource  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5590                                              False
# 5591                                              False
# 5592                                              False
# 5593                                              False
# 5594                                              False
#
#       internalId  progress.overdueCount  progress.totalCount  \
# 0          19073                      0                    1
# 1          19072                      0                    1
# 2          19070                      0                    6
# 3          19069                      0                    6
# 4          19067                      0                    0
# ...          ...                    ...                  ...
# 5590        9405                      0                    3
# 5591        9404                      0                    3
# 5592        8657                      0                   21
# 5593        8655                      0                   18
# 5594        8480                      0                   21
#
#       progress.finishedCount               dateCreated references        id  \
# 0                          1  2024-05-22T10:35:12+0000         []  29873704
# 1                          1  2024-05-22T10:33:54+0000         []  29873692
# 2                          6  2024-05-22T10:30:51+0000         []  29873659
# 3                          6  2024-05-22T10:30:08+0000         []  29873656
# 4                          0  2024-05-22T10:14:20+0000         []  29873532
# ...                      ...                       ...        ...       ...
# 5590                       3  2023-04-27T10:43:06+0000         []  27046129
# 5591                       3  2023-04-27T10:19:56+0000         []  27045950
# 5592                      21  2023-03-29T16:39:52+0000         []  26835211
# 5593                      18  2023-03-29T15:33:33+0000         []  26834883
# 5594                      21  2023-03-17T12:29:55+0000         []  26749576
#
#      analyseSettings.id targetLangs  ... qualityAssuranceSettings.id  \
# 0             304519280        [en]  ...                    36614371
# 1             304519066        [en]  ...                    36614351
# 2             304518563        [en]  ...                    36614297
# 3             304518470        [en]  ...                    36614291
# 4             304514948        [en]  ...                    36614117
# ...                 ...         ...  ...                         ...
# 5590          270159445        [en]  ...                    32249511
# 5591          270156543        [en]  ...                    32249255
# 5592          267640875        [en]  ...                    31928507
# 5593          267637114        [en]  ...                    31927990
# 5594          266618062        [en]  ...                    31801016
#
#      costCenter domain isPublishedOnJobBoard archived shared         userRole  \
# 0          None   None                 False    False  False  PROJECT_MANAGER
# 1          None   None                 False    False  False  PROJECT_MANAGER
# 2          None   None                 False    False  False  PROJECT_MANAGER
# 3          None   None                 False    False  False  PROJECT_MANAGER
# 4          None   None                 False    False  False  PROJECT_MANAGER
# ...         ...    ...                   ...      ...    ...              ...
# 5590       None   None                 False    False  False  PROJECT_MANAGER
# 5591       None   None                 False    False  False  PROJECT_MANAGER
# 5592       None   None                 False    False  False  PROJECT_MANAGER
# 5593       None   None                 False    False  False  PROJECT_MANAGER
# 5594       None   None                 False    False  False  PROJECT_MANAGER
#
#      accessSettings.id                          mtSettingsPerLanguageList  \
# 0             35899616  [{'machineTranslateSettings': {'type': 'MEMSOU...
# 1             35899596  [{'machineTranslateSettings': {'type': 'MEMSOU...
# 2             35899542  [{'machineTranslateSettings': {'type': 'MEMSOU...
# 3             35899536  [{'machineTranslateSettings': {'type': 'MEMSOU...
# 4             35899363  [{'machineTranslateSettings': {'type': 'MEMSOU...
# ...                ...                                                ...
# 5590          31814363  [{'machineTranslateSettings': {'type': 'MEMSOU...
# 5591          31814107  [{'machineTranslateSettings': {'type': 'MEMSOU...
# 5592          31497286  [{'machineTranslateSettings': {'type': 'MEMSOU...
# 5593          31496775  [{'machineTranslateSettings': {'type': 'MEMSOU...
# 5594          31371164  [{'machineTranslateSettings': {'type': 'MEMSOU...
#
#                                           workflowSteps
# 0     [{'workflowLevel': 1, 'abbreviation': 'EX', 'w...
# 1     [{'workflowLevel': 1, 'abbreviation': 'EX', 'w...
# 2     [{'workflowLevel': 1, 'abbreviation': 'EX', 'w...
# 3     [{'workflowLevel': 1, 'abbreviation': 'EX', 'w...
# 4     [{'workflowLevel': 1, 'abbreviation': 'EX', 'w...
# ...                                                 ...
# 5590  [{'workflowLevel': 1, 'abbreviation': 'L', 'wo...
# 5591  [{'workflowLevel': 1, 'abbreviation': 'L', 'wo...
# 5592  [{'workflowLevel': 1, 'abbreviation': 'L', 'wo...
# 5593  [{'workflowLevel': 1, 'abbreviation': 'L', 'wo...
# 5594  [{'workflowLevel': 1, 'abbreviation': 'L', 'wo...
#
# [5595 rows x 48 columns]

# %%
# Criar o DataFrame
df = pd.DataFrame(projects_list)

columns_of_interest = [
    'internalId', 'dateCreated', 'id', 'dateDue', 'name', 'type', 
    'client.name', 'status',
    'isPublishedOnJobBoard', 'archived']

# Criar um novo DataFrame com apenas as colunas específicas
df = df[columns_of_interest]

# Filtrar projetos com dateCreated no ano de 2024
df['dateCreated'] = pd.to_datetime(df['dateCreated'])
df = df[df['dateCreated'].dt.year == 2024]

#Converter as colunas de data para o formato YYYY-MM-DD
df['dateCreated'] = pd.to_datetime(df['dateCreated']).dt.strftime('%Y-%m-%d')
df['dateDue'] = pd.to_datetime(df['dateDue']).dt.strftime('%Y-%m-%d')

df
# Out:
#       internalId dateCreated        id     dateDue  \
# 0          19073  2024-05-22  29873704  2024-05-27
# 1          19072  2024-05-22  29873692  2024-05-27
# 2          19070  2024-05-22  29873659  2024-05-27
# 3          19069  2024-05-22  29873656  2024-05-27
# 4          19067  2024-05-22  29873532  2024-05-27
# ...          ...         ...       ...         ...
# 1577       16133  2024-01-01  28834913  2024-01-01
# 1578       16132  2024-01-01  28834902  2024-01-01
# 1579       16131  2024-01-01  28834895  2024-01-01
# 1580       16130  2024-01-01  28834891  2024-01-01
# 1581       16129  2024-01-01  28834889  2024-01-01
#
#                                name     type  client.name status  \
# 0          #8216_canadian_5/22/2024  PROJECT  Harris Poll    NEW
# 1           #8215_spanish_5/22/2024  PROJECT  Harris Poll    NEW
# 2     #8214_portuguese_br_5/22/2024  PROJECT  Harris Poll    NEW
# 3           #8213_italian_5/22/2024  PROJECT  Harris Poll    NEW
# 4          #8212_canadian_5/22/2024  PROJECT  Harris Poll    NEW
# ...                             ...      ...          ...    ...
# 1577          #6716_german_1/1/2024  PROJECT  Harris Poll    NEW
# 1578        #6715_japanese_1/1/2024  PROJECT  Harris Poll    NEW
# 1579          #6714_german_1/1/2024  PROJECT  Harris Poll    NEW
# 1580        #6713_japanese_1/1/2024  PROJECT  Harris Poll    NEW
# 1581   #6712_portuguese_br_1/1/2024  PROJECT  Harris Poll    NEW
#
#       isPublishedOnJobBoard  archived
# 0                     False     False
# 1                     False     False
# 2                     False     False
# 3                     False     False
# 4                     False     False
# ...                     ...       ...
# 1577                  False     False
# 1578                  False     False
# 1579                  False     False
# 1580                  False     False
# 1581                  False     False
#
# [1582 rows x 10 columns]

# %%
# Função para obter o Analysis UID de um projeto
def get_analysis_uid(project_id):
    get_list_analyses_project = f"https://cloud.memsource.com/web/api2/v3/projects/{project_id}/analyses"
    response = requests.get(get_list_analyses_project, headers=headers)
    
    if response.status_code == 200:
        analyses_data = response.json()
        if analyses_data and 'content' in analyses_data and analyses_data['content']:
            return analyses_data['content'][0]['uid']
    return None

# Adicionar a coluna 'Analysis_uID' no DataFrame
df['Analysis_uID'] = df['id'].apply(lambda x: get_analysis_uid(x))
df
# Out:
#       internalId dateCreated        id     dateDue  \
# 0          19073  2024-05-22  29873704  2024-05-27
# 1          19072  2024-05-22  29873692  2024-05-27
# 2          19070  2024-05-22  29873659  2024-05-27
# 3          19069  2024-05-22  29873656  2024-05-27
# 4          19067  2024-05-22  29873532  2024-05-27
# ...          ...         ...       ...         ...
# 1577       16133  2024-01-01  28834913  2024-01-01
# 1578       16132  2024-01-01  28834902  2024-01-01
# 1579       16131  2024-01-01  28834895  2024-01-01
# 1580       16130  2024-01-01  28834891  2024-01-01
# 1581       16129  2024-01-01  28834889  2024-01-01
#
#                                name     type  client.name status  \
# 0          #8216_canadian_5/22/2024  PROJECT  Harris Poll    NEW
# 1           #8215_spanish_5/22/2024  PROJECT  Harris Poll    NEW
# 2     #8214_portuguese_br_5/22/2024  PROJECT  Harris Poll    NEW
# 3           #8213_italian_5/22/2024  PROJECT  Harris Poll    NEW
# 4          #8212_canadian_5/22/2024  PROJECT  Harris Poll    NEW
# ...                             ...      ...          ...    ...
# 1577          #6716_german_1/1/2024  PROJECT  Harris Poll    NEW
# 1578        #6715_japanese_1/1/2024  PROJECT  Harris Poll    NEW
# 1579          #6714_german_1/1/2024  PROJECT  Harris Poll    NEW
# 1580        #6713_japanese_1/1/2024  PROJECT  Harris Poll    NEW
# 1581   #6712_portuguese_br_1/1/2024  PROJECT  Harris Poll    NEW
#
#       isPublishedOnJobBoard  archived  Analysis_word_all  \
# 0                     False     False                  0
# 1                     False     False                  0
# 2                     False     False                  0
# 3                     False     False                  0
# 4                     False     False                  0
# ...                     ...       ...                ...
# 1577                  False     False                  0
# 1578                  False     False                  0
# 1579                  False     False                  0
# 1580                  False     False                  0
# 1581                  False     False                  0
#
#                 Analysis_uID
# 0     pnxgJqzNOupPapq0F54xl4
# 1     9lmHmQC8crW17OAnE6kDG6
# 2     Ggns53fqRC916qJpbdGO1d
# 3     lyYLaT8ykN9Kc9oWdHoNq0
# 4                       None
# ...                      ...
# 1577  vWqlAMxRj0Ro5WmK0U1MWs
# 1578  YsadQaGINN9edRA5i2zlq2
# 1579  kzcvMAhWp0kf7asDvDLoi6
# 1580                    None
# 1581                    None
#
# [1582 rows x 12 columns]

# %%
# Função para obter a soma das palavras de uma análise
def get_analysis_words(analyseUid):
    get_analysis = f"https://cloud.memsource.com/web/api2/v3/analyses/{analyseUid}"
    response = requests.get(get_analysis, headers=headers)
    
    if response.status_code == 200:
        analysis_data = response.json()
        total_words = 0
        if 'analyseLanguageParts' in analysis_data:
            for part in analysis_data['analyseLanguageParts']:
                if 'data' in part:
                    for key in part['data']:
                        if isinstance(part['data'][key], dict) and 'words' in part['data'][key]:
                            total_words += int(part['data'][key]['words'])
        return total_words
    return 0

# Adicionar a coluna 'Analysis_word_all' no DataFrame usando os valores da coluna 'Analysis_uID'
df['Analysis_word_all'] = df['Analysis_uID'].apply(lambda uid: get_analysis_words(uid) if uid else 0)

df
# Out:
#       internalId dateCreated        id     dateDue  \
# 0          19073  2024-05-22  29873704  2024-05-27
# 1          19072  2024-05-22  29873692  2024-05-27
# 2          19070  2024-05-22  29873659  2024-05-27
# 3          19069  2024-05-22  29873656  2024-05-27
# 4          19067  2024-05-22  29873532  2024-05-27
# ...          ...         ...       ...         ...
# 1577       16133  2024-01-01  28834913  2024-01-01
# 1578       16132  2024-01-01  28834902  2024-01-01
# 1579       16131  2024-01-01  28834895  2024-01-01
# 1580       16130  2024-01-01  28834891  2024-01-01
# 1581       16129  2024-01-01  28834889  2024-01-01
#
#                                name     type  client.name status  \
# 0          #8216_canadian_5/22/2024  PROJECT  Harris Poll    NEW
# 1           #8215_spanish_5/22/2024  PROJECT  Harris Poll    NEW
# 2     #8214_portuguese_br_5/22/2024  PROJECT  Harris Poll    NEW
# 3           #8213_italian_5/22/2024  PROJECT  Harris Poll    NEW
# 4          #8212_canadian_5/22/2024  PROJECT  Harris Poll    NEW
# ...                             ...      ...          ...    ...
# 1577          #6716_german_1/1/2024  PROJECT  Harris Poll    NEW
# 1578        #6715_japanese_1/1/2024  PROJECT  Harris Poll    NEW
# 1579          #6714_german_1/1/2024  PROJECT  Harris Poll    NEW
# 1580        #6713_japanese_1/1/2024  PROJECT  Harris Poll    NEW
# 1581   #6712_portuguese_br_1/1/2024  PROJECT  Harris Poll    NEW
#
#       isPublishedOnJobBoard  archived  Analysis_word_all  \
# 0                     False     False                 56
# 1                     False     False                 55
# 2                     False     False                242
# 3                     False     False               1063
# 4                     False     False                  0
# ...                     ...       ...                ...
# 1577                  False     False                 16
# 1578                  False     False                712
# 1579                  False     False                748
# 1580                  False     False                  0
# 1581                  False     False                  0
#
#                 Analysis_uID
# 0     pnxgJqzNOupPapq0F54xl4
# 1     9lmHmQC8crW17OAnE6kDG6
# 2     Ggns53fqRC916qJpbdGO1d
# 3     lyYLaT8ykN9Kc9oWdHoNq0
# 4                       None
# ...                      ...
# 1577  vWqlAMxRj0Ro5WmK0U1MWs
# 1578  YsadQaGINN9edRA5i2zlq2
# 1579  kzcvMAhWp0kf7asDvDLoi6
# 1580                    None
# 1581                    None
#
# [1582 rows x 12 columns]

# %%
df.to_excel("projects_harris_poll.xlsx", index=False)

# %%
project_id = "29873704"

# %%
get_project = f"https://cloud.memsource.com/web/api2/v1/projects/{project_id}"
get_list_analyses_project = f"https://cloud.memsource.com/web/api2/v3/projects/{project_id}/analyses"

# %%
headers = {
    "Authorization": f"ApiToken {access_token}"
}

response = requests.get(get_list_analyses_project, headers=headers)

if response.status_code == 200:
    project_info = response.json()
else:
    # Handle errors (e.g., project not found, authentication error)
    print("Failed to retrieve project information. Status code:", response.status_code)
    print("Response:", response.text)

response.json()
# Out:
# {'pageNumber': 0,
#  'content': [{'netRateScheme': None,
#    'innerId': '1',
#    'importStatus': {'status': 'OK', 'errorMessage': None},
#    'type': 'PreAnalyse',
#    'uid': 'pnxgJqzNOupPapq0F54xl4',
#    'createdBy': {'userName': 'amira.youssef_PM',
#     'uid': 'seh9BcQs0vm1Z4eoMGlMFc',
#     'id': '922171',
#     'firstName': 'Amira',
#     'lastName': 'Youssef',
#     'role': 'PROJECT_MANAGER',
#     'email': 'amira.youssef@locaria.com'},
#    'dateCreated': '2024-05-22T10:35:36+0000',
#    'id': '159613234',
#    'analyseLanguageParts': [{'jobs': [{'innerId': '1',
#        'uid': 'AaN9fnNWdWWffZBPY2ELr0',
#        'filename': 'l0_option_selfserve53b240506_QRA_QRA_Thinking about a time when an employee was being _ipr.xml'}],
#      'id': '174538347',
#      'sourceLang': 'fr_ca',
#      'targetLang': 'en'}],
#    'pureWarnings': [],
#    'outdated': False,
#    'provider': None,
#    'name': 'Analysis #1'}],
#  'numberOfElements': 1,
#  'totalElements': 1,
#  'pageSize': 50,
#  'totalPages': 1}

# %%
analyseUid = "pnxgJqzNOupPapq0F54xl4" 
get_analysis = f"https://cloud.memsource.com/web/api2/v3/analyses/{analyseUid}"

# %%
headers = {
    "Authorization": f"ApiToken {access_token}"
}

response = requests.get(get_analysis, headers=headers)

if response.status_code == 200:
    project_info = response.json()
else:
    # Handle errors (e.g., project not found, authentication error)
    print("Failed to retrieve project information. Status code:", response.status_code)
    print("Response:", response.text)

response.json()
# Out:
# {'importStatus': {'status': 'OK', 'errorMessage': None},
#  'dateCreated': '2024-05-22T10:35:36+0000',
#  'id': '159613234',
#  'analyseLanguageParts': [{'jobs': [{'innerId': '1',
#      'uid': 'AaN9fnNWdWWffZBPY2ELr0',
#      'filename': 'l0_option_selfserve53b240506_QRA_QRA_Thinking about a time when an employee was being _ipr.xml'}],
#    'discountedData': None,
#    'id': '174538347',
#    'sourceLang': 'fr_ca',
#    'data': {'available': True,
#     'internalFuzzyMatches': {'match50': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match0': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match95': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match85': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match100': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match75': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0}},
#     'machineTranslationMatches': {'match50': {'editingTime': 0.0,
#       'percent': 46.42857142857143,
#       'words': 26.0,
#       'segments': 2.0,
#       'characters': 113.0,
#       'normalizedPages': 0.07611111111111112},
#      'match0': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match95': {'editingTime': 0.0,
#       'percent': 5.357142857142857,
#       'words': 3.0,
#       'segments': 1.0,
#       'characters': 13.0,
#       'normalizedPages': 0.008333333333333333},
#      'match85': {'editingTime': 0.0,
#       'percent': 21.428571428571427,
#       'words': 12.0,
#       'segments': 1.0,
#       'characters': 58.0,
#       'normalizedPages': 0.03833333333333333},
#      'match100': {'editingTime': 0.0,
#       'percent': 10.714285714285714,
#       'words': 6.0,
#       'segments': 2.0,
#       'characters': 22.0,
#       'normalizedPages': 0.014444444444444444},
#      'match75': {'editingTime': 0.0,
#       'percent': 14.285714285714285,
#       'words': 8.0,
#       'segments': 1.0,
#       'characters': 29.0,
#       'normalizedPages': 0.02}},
#     'estimate': False,
#     'all': {'editingTime': 0.0,
#      'percent': 100.0,
#      'words': 56.0,
#      'segments': 8.0,
#      'characters': 240.0,
#      'normalizedPages': 0.16},
#     'repetitions': {'editingTime': 0.0,
#      'percent': 0.0,
#      'words': 0.0,
#      'segments': 0.0,
#      'characters': 0.0,
#      'normalizedPages': 0.0},
#     'transMemoryMatches': {'match50': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match101': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match0': {'editingTime': 0.0,
#       'percent': 1.7857142857142856,
#       'words': 1.0,
#       'segments': 1.0,
#       'characters': 5.0,
#       'normalizedPages': 0.002777777777777778},
#      'match95': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match85': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match100': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match75': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0}},
#     'nonTranslatablesMatches': {'match50': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match0': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match95': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match85': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match100': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0},
#      'match75': {'editingTime': 0.0,
#       'percent': 0.0,
#       'words': 0.0,
#       'segments': 0.0,
#       'characters': 0.0,
#       'normalizedPages': 0.0}}},
#    'transMemories': [],
#    'targetLang': 'en'}],
#  'outdated': False,
#  'name': 'Analysis #1',
#  'netRateScheme': None,
#  'settings': {'includeNumbers': True,
#   'includeNonTranslatables': True,
#   'includeFuzzyRepetitions': False,
#   'type': 'PreAnalyse',
#   'namingPattern': 'Analysis #{innerId}',
#   'includeConfirmedSegments': True,
#   'countSourceUnits': True,
#   'analyzeByLanguage': False,
#   'analyzeByProvider': False,
#   'includeMachineTranslationMatches': True,
#   'includeLockedSegments': True,
#   'separateFuzzyRepetitions': False,
#   'includeTransMemory': True,
#   'allowAutomaticPostAnalysis': False},
#  'innerId': 1,
#  'type': 'PreAnalyse',
#  'uid': 'pnxgJqzNOupPapq0F54xl4',
#  'createdBy': {'userName': 'amira.youssef_PM',
#   'uid': 'seh9BcQs0vm1Z4eoMGlMFc',
#   'id': '922171',
#   'firstName': 'Amira',
#   'lastName': 'Youssef',
#   'role': 'PROJECT_MANAGER',
#   'email': 'amira.youssef@locaria.com'},
#  'canChangeNetRateScheme': True,
#  'pureWarnings': [],
#  'project': {'uid': 'HG092U6tf7h6fawyb5I6p0',
#   'name': '#8216_canadian_5/22/2024'},
#  'provider': None}
